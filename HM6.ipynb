# %% [markdown]
# <a href="https://colab.research.google.com/github/peoplecallitinsanity/CVC-hm/blob/main/HM6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a align="left" href="https://ultralytics.com/yolov5" target="_blank">
# <img width="1024", src="https://user-images.githubusercontent.com/26833433/125273437-35b3fc00-e30d-11eb-9079-46f313325424.png"></a>
#
# This is the **official YOLOv5 🚀 notebook** by **Ultralytics**, and is freely available for redistribution under the [GPL-3.0 license](https://choosealicense.com/licenses/gpl-3.0/).
# For more information please visit https://github.com/ultralytics/yolov5 and https://ultralytics.com. Thank you!

# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

from yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.0-111-g94d8fec torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
# Setup complete ✅

# %%
# !unzip --q ../traindata2.zip -d ../
# Out:
# Archive:  ../traindata2.zip
#    creating: ../traindata2/
#    creating: ../traindata2/images/
#    creating: ../traindata2/images/train/
#   inflating: ../traindata2/images/train/A104.jpg
#   inflating: ../traindata2/images/train/A113.jpg
#   inflating: ../traindata2/images/train/A114.jpg
#   inflating: ../traindata2/images/train/A1148.jpg
#   inflating: ../traindata2/images/train/A122.jpg
#   inflating: ../traindata2/images/train/A149.jpg
#   inflating: ../traindata2/images/train/A173.jpg
#   inflating: ../traindata2/images/train/A1823.jpg
#   inflating: ../traindata2/images/train/A1824.jpg
#   inflating: ../traindata2/images/train/A1826.jpg
#   inflating: ../traindata2/images/train/A1837.jpg
#   inflating: ../traindata2/images/train/A1857.jpg
#   inflating: ../traindata2/images/train/A1887.jpg
#   inflating: ../traindata2/images/train/A1891.jpg
#   inflating: ../traindata2/images/train/A224.jpg
#   inflating: ../traindata2/images/train/A225.jpg
# ...

# %%
# !python train.py --img 320 --batch 16 --epochs 100 --data custom_data.yaml --weights yolov5m.pt --cache
# Out:
# train: weights=yolov5m.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=100, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-86-g7473f0f torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python detect.py --weights /content/best.pt --conf 0.25 --source A49.jpg
# Out:
# detect: weights=['/content/best.pt'], source=A49.jpg, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-111-g94d8fec torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 290 layers, 20962041 parameters, 0 gradients, 48.3 GFLOPs
# image 1/1 /content/yolov5/A49.jpg: 640x640 1 A, Done. (0.085s)
# Speed: 0.6ms pre-process, 84.9ms inference, 17.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('/content/yolov5/runs/detect/exp3/A49.jpg') # reads image
plt.imshow(img)

# %%
# !python detect.py --weights /content/best.pt --conf 0.25 --source C144.jpg
# Out:
# detect: weights=['/content/best.pt'], source=C144.jpg, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-111-g94d8fec torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 290 layers, 20962041 parameters, 0 gradients, 48.3 GFLOPs
# image 1/1 /content/yolov5/C144.jpg: 640x640 1 C, Done. (0.085s)
# Speed: 0.6ms pre-process, 84.6ms inference, 2.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp4

# %%
img = cv2.imread('/content/yolov5/runs/detect/exp4/C144.jpg') # reads image
plt.imshow(img)

# %%
# !python detect.py --weights /content/best.pt --conf 0.25 --source F480.jpg
# Out:
# detect: weights=['/content/best.pt'], source=F480.jpg, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-111-g94d8fec torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 290 layers, 20962041 parameters, 0 gradients, 48.3 GFLOPs
# image 1/1 /content/yolov5/F480.jpg: 480x640 1 F, Done. (0.074s)
# Speed: 0.5ms pre-process, 74.4ms inference, 1.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp5

# %%
img = cv2.imread('/content/yolov5/runs/detect/exp5/F480.jpg') # reads image
plt.imshow(img)
